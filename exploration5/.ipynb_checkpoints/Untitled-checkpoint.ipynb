# %%
import face_recognition
import os
# %matplotlib inline
import matplotlib.pyplot as plt

image_path = os.getenv('HOME')+'/aiffel/face_embedding/images/obama.jpg'
image = face_recognition.load_image_file(image_path)
face_locations = face_recognition.face_locations(image)

print(face_locations)  # 이미지에서 얼굴 영역의 좌표를 출력합니다.

a, b, c, d = face_locations[0]
cropped_face = image[a:c,d:b,:]

plt.imshow(cropped_face)   # 이미지에서 얼굴영역만 잘라낸 cropped_face를 그려 봅니다.
# Out:
# [(98, 758, 284, 572)]

# %%
os.getenv('HOME')
# Out:
# '/aiffel'

# %%
cd aiffel
# Out:
# /aiffel/aiffel

# %%
import face_recognition
import os
# %matplotlib inline
import matplotlib.pyplot as plt

image_path = os.getenv('HOME')+"/aiffel/exploration/data/ex5_Image/개리.jpg"
image = face_recognition.load_image_file(image_path)
face_locations = face_recognition.face_locations(image)

print(face_locations)  # 이미지에서 얼굴 영역의 좌표를 출력합니다.

a, b, c, d = face_locations[0]
cropped_face = image[a:c,d:b,:]

plt.imshow(cropped_face)   # 이미지에서 얼굴영역만 잘라낸 cropped_face를 그려 봅니다.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-87-4a6bfac4b14a> in <module>
#       5
#       6 image_path = os.getenv('HOME')+"/aiffel/exploration/data/ex5_Image/개리.jpg"
# ----> 7 image = face_recognition.load_image_file(image_path)
#       8 face_locations = face_recognition.face_locations(image)
#       9
#
# /opt/conda/lib/python3.7/site-packages/face_recognition/api.py in load_image_file(file, mode)
#      84     :return: image contents as numpy array
#      85     """
# ---> 86     im = PIL.Image.open(file)
#      87     if mode:
#      88         im = im.convert(mode)
#
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py in open(fp, mode, formats)
#    2902
#    2903     if filename:
# -> 2904         fp = builtins.open(filename, "rb")
#    2905         exclusive_fp = True
#    2906
#
# ...

# %%
import face_recognition
import os

def get_cropped_face(image_file):
    image = face_recognition.load_image_file(image_file)
    face_locations = face_recognition.face_locations(image)
    
    a, b, c, d = face_locations[0]
    cropped_face = image[a:c, d:b, :]
    
    return cropped_face

# %%
import numpy as np

dir_path = os.getenv('HOME')+'/aiffel/face_embedding/images'
image_file = os.path.join(dir_path, 'obama.jpg')
face = get_cropped_face(image_file)   # 얼굴 영역을 구하는 함수(이전 스텝에서 구현)

# 얼굴 영역을 가지고 얼굴 임베딩 벡터를 구하는 함수
def get_face_embedding(face):
    return face_recognition.face_encodings(face)

embedding = get_face_embedding(face)  
np.array(embedding).shape
# Out:
# (1, 128)

# %%
def get_face_embedding_dict(dir_path):
    file_list = os.listdir(dir_path)
    embedding_dict = {}
    
    for file in file_list:
        image_file = os.path.join(dir_path, file)
        face = get_cropped_face(image_file)
        embedding = get_face_embedding(face)
        if len(embedding) > 0:
            name = os.path.splitext(file)[0]
            embedding_dict[name] = embedding[0]
        
    return embedding_dict

# %%
embedding_dict = get_face_embedding_dict(dir_path)
embedding_dict['trump']
# Out:
# array([-0.15962467,  0.20268655,  0.0323635 ,  0.02439232, -0.06226439,
#         0.05140705,  0.07351795, -0.16823348,  0.06962204, -0.05557961,
#         0.17270109, -0.05094168, -0.35293093, -0.0316438 ,  0.03792984,
#         0.17343847, -0.13260126, -0.15357377, -0.23523533, -0.08442692,
#        -0.00134139,  0.03210667, -0.08926154, -0.02670781, -0.09581181,
#        -0.25792354, -0.01056999, -0.11071672,  0.03133569, -0.07444921,
#         0.05670552, -0.02273796, -0.19461137, -0.04576054,  0.00947582,
#         0.01806056, -0.1502624 , -0.07787319,  0.17577608,  0.01933258,
#        -0.19744575, -0.03930519,  0.07374467,  0.20196027,  0.1476755 ,
#        -0.0141539 ,  0.0172476 , -0.11976205,  0.09462971, -0.24318144,
#        -0.02755127,  0.12169892,  0.14837705,  0.17079785,  0.06952555,
#        -0.15360466,  0.02005427,  0.08199155, -0.19544823,  0.10653654,
#         0.11468476, -0.21902837, -0.07677591, -0.06791042,  0.10587606,
# ...

# %%
def get_distance(name1, name2):
    return np.linalg.norm(embedding_dict[name1]-embedding_dict[name2], ord=2)

get_distance('obama', 'trump')
# Out:
# 0.8885117374787042

# %%
def get_nearest_face(name, top=5): 
    pass
get_nearest_face('trump')

# %%
# name1과 name2의 거리를 비교하는 함수를 생성하되, name1은 미리 지정하고, name2는 호출시에 인자로 받도록 합니다.
def get_sort_key_func(name1):
    def get_distance_from_name1(name2):
        return get_distance(name1, name2)
    return get_distance_from_name1

sort_key_func = get_sort_key_func('trump')   
# 이렇게 생성된 함수 sort_key_func는 sort_key_func('obama') 라고 호출할 때 trump와 obama 사이의 임베딩 벡터 거리를 계산합니다.

# %%
a = sorted(embedding_dict.items(), key=lambda x:sort_key_func(x[0]))

# %%
b = dict(a)

# %%
def get_nearest_face(name, top=5):
    sort_key_func = get_sort_key_func(name)
    sorted_dict = dict(sorted(embedding_dict.items(), key = lambda x : sort_key_func(x[0])))
    for index, key in enumerate(sorted_dict.keys()):
        if index + 1 <= top:
            distance = get_distance(name, key)
            print(f"순위 {index + 1} : {key}, {distance}")

# %%
get_nearest_face('obama')
# Out:
# 순위 1 : obama, 0.0
# 순위 2 : biden, 0.846720652777963
# 순위 3 : bush, 0.8639189288560225
# 순위 4 : reagan, 0.8692435806803928
# 순위 5 : trump, 0.8885117374787042

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1SCNlkW3l9bzsGhzFVk8DmNdfq9D-sey2' -O celebrity.tar
# Out:
# --2021-07-29 07:46:13--  https://docs.google.com/uc?export=download&id=1SCNlkW3l9bzsGhzFVk8DmNdfq9D-sey2
# Resolving docs.google.com (docs.google.com)... 142.251.32.206, 2607:f8b0:4023:1006::8b, 2607:f8b0:4023:1006::8a, ...
# Connecting to docs.google.com (docs.google.com)|142.251.32.206|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-88-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/rsgq8e2h46qpm0hh1kthu22mg43ipqjg/1627544775000/10955108029758794712/*/1SCNlkW3l9bzsGhzFVk8DmNdfq9D-sey2?e=download [following]
# ...
# --2021-07-29 07:46:17--  https://doc-0g-88-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/rsgq8e2h46qpm0hh1kthu22mg43ipqjg/1627544775000/10955108029758794712/*/1SCNlkW3l9bzsGhzFVk8DmNdfq9D-sey2?e=download
# Resolving doc-0g-88-docs.googleusercontent.com (doc-0g-88-docs.googleusercontent.com)... 142.250.138.132, 2607:f8b0:4023:1006::84
# ...

# %%
# !ls
# Out:
# Untitled.ipynb

# %%
# !cd ../data

# %%
# !pwd
# Out:
# /aiffel/aiffel/exploration/exploration5

# %%
cd ../data/ex5_Image
# Out:
# /aiffel/aiffel/exploration/data/ex5_Image

# %%
# !ls
# Out:
# celebrity  celebrity.tar  selfi2.jpg  selfi3.jpg

# %%
# !mv selfi2.jpg jiwoo1.jpg

# %%
# !mv selfi3.jpg jiwoo2.jpg

# %%
# !mv jiwoo1.jpg  jiwoo2.jpg celebrity

# %%
# !ls
# Out:
# celebrity  celebrity.tar

# %%
cd celebrity
# Out:
# /aiffel/aiffel/exploration/data/ex5_Image/celebrity

# %%
import face_recognition
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
dir_path = os.getenv('HOME')+"/aiffel/exploration/data/ex5_Image/celebrity"

def get_cropped_face(image_file):
    image = face_recognition.load_image_file(image_file)
    face_locations = face_recognition.face_locations(image)
    
    a, b, c, d = face_locations[0]
    cropped_face = image[a:c, d:b, :]
    
    return cropped_face

# %%
def get_face_embedding(face):
    return face_recognition.face_encodings(face)

# %%
def get_face_embedding_dict(dir_path):
    file_list = os.listdir(dir_path)
    embedding_dict = {}
    del_name = ["개리", "김대명", "도아", "드웨인 존슨", "마동석", "사무엘 L 잭슨", 
                "신비", "신태용", "유아", "이승환", "이용진", "이희준","전소미", "한효주", 
                "bush", "비니", "씨잼", "이명박", "최민식", "biden", "산들", "목진화", "영알남", "이말년"]
    
    for file in file_list:
        image_file = os.path.join(dir_path, file)
        
        if file.split(".")[0] in del_name:
            continue
        face = get_cropped_face(image_file)
        embedding = get_face_embedding(face)
        if len(embedding) > 0:
            name = os.path.splitext(file)[0]
            embedding_dict[name] = embedding[0]
        
    return embedding_dict

# %%
cd ~/aiffel/exploration/data/ex5_Image/celebrity
# Out:
# /aiffel/aiffel/exploration/data/ex5_Image/celebrity

# %%
embedding_dict = get_face_embedding_dict(dir_path)

# %%
def get_distance(name1, name2):
    return np.linalg.norm(embedding_dict[name1]-embedding_dict[name2], ord=2)

# %%
get_distance("jiwoo0", "jiwoo1")
# Out:
# 0.3412031156299035

# %%
def get_sort_key_func(name1):
    def get_distance_from_name1(name2):
        return get_distance(name1, name2)
    return get_distance_from_name1

# %%
def get_nearest_face(name, top=5):
    sort_key_func = get_sort_key_func(name)
    sorted_dict = dict(sorted(embedding_dict.items(), key = lambda x : sort_key_func(x[0])))
    for index, key in enumerate(sorted_dict.keys()):
        if key == "jiwoo0" or key == "jiwoo1":
            continue
        if index + 1 <= top + 2:
            distance = get_distance(name, key)
            print(f"순위 {index - 1} : {key}, {distance}")

# %%
get_nearest_face("jiwoo0")
# Out:
# 순위 1 : 박명수, 0.3741970613356474
# 순위 2 : 이승철, 0.3986431464978788
# 순위 3 : 박해일, 0.4131532913616255
# 순위 4 : 대도서관, 0.41383465116971024
# 순위 5 : 조정치, 0.4246706346644485

# %%
file_list = os.listdir(dir_path)

# %%
key in file_list.split["."][0]
# Out:
# ['신태용.jpg',
#  '이동휘.jpg',
#  '지드래곤.jpeg',
#  '케이.jpg',
#  '이대호.jpeg',
#  '공유.jpg',
#  '레드벨벳웬디.jpg',
#  '권태원.jpeg',
#  '이승기.jpeg',
#  '태연.jpg',
#  '수호.jpg',
#  '최양락.jpg',
#  '존 파브르.jpeg',
#  '서강준.jpg',
#  '장도연.jpg',
#  '첸.jpg',
#  '제니.jpg',
#  '유노윤호.jpg',
#  '박신양.png',
#  '이승철.jpeg',
#  '트와이스쯔위.jpg',
#  '한효주.jpg',
#  '김상호.png',
#  '이광수.jpg',
#  'b1a4진영.jpeg',
#  '이제훈.jpeg',
#  '신비.jpg',
#  '정국.jpg',
#  '박진영.jpeg',
#  '유재석.jpg',
#  '조이.jpg',
#  '지코.jpg',
#  '김대중.jpg',
#  '김고은.jpeg',
#  '김대명.jpeg',
#  '손흥민.jpg',
#  '로다주.jpeg',
#  '최민식.jpg',
#  '잇섭.png',
#  '이동국.jpeg',
#  '류현진.jpg',
#  '전소미.jpg',
#  '박찬욱.jpeg',
#  'obama.jpg',
#  '아이즈원김채원.jpg',
#  '레인보우재경.jpg',
#  '마크 러팔로.jpeg',
#  '봉준호.jpg',
#  '강미나.jpg',
#  '김현수.jpeg',
#  '수지.jpg',
#  '온앤오프라운.jpg',
#  '이연걸.jpeg',
#  '개리.jpg',
#  '박휘순.jpg',
#  '목진화.png',
#  '김광현.jpg',
#  '유희열.jpeg',
#  '잭 니콜슨.jpeg',
#  '한석규.jpg',
#  '민니.jpg',
#  '조달환.png',
#  '윤아.jpg',
#  '잇지예지.jpeg',
#  '하정우.jpg',
#  '김래원.jpeg',
#  '브래들리 쿠퍼.jpg',
#  '산들.jpeg',
# ...

# %%
file_list = os.listdir(dir_path)
name_list = []

# %%
get_file_path(dir_path, "제니")
# Out:
# '/aiffel/aiffel/exploration/data/ex5_Image/celebrity/제니.jpg'

# %% [markdown]
# 내 얼굴이 가장 가까운 것을 알 수 있다

# %%
def get_file_path(dir_path, name):
    file_list = os.listdir(dir_path)
    for index, file in enumerate(file_list):
        if name == file.split(".")[0] :
            file_path = os.path.join(dir_path, file)
    return file_path

# %%
import matplotlib.pyplot as plt

# %%
def display_celebrity(name, top = 5):
    plt.figure(figsize = (18, 12))
    sort_key_func = get_sort_key_func(name)
    
    
    sorted_dict = dict(sorted(embedding_dict.items(), key = lambda x : sort_key_func(x[0])))
    for index, key in enumerate(sorted_dict.keys()):
        if index + 1 <= top:
            plt.subplot(1,5, index+1)
            image = face_recognition.load_image_file(get_file_path(dir_path, key))
            plt.imshow(image)

# %%
display_celebrity("jiwoo0")
