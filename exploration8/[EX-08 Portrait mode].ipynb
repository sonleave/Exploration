# %%
import cv2
import numpy as np
import os
import tarfile
import urllib

from matplotlib import pyplot as plt
import tensorflow as tf

# %%
import os
img_path = os.getenv('HOME')+'/aiffel/human_segmentation/images/image1.jpg' 
img_orig = cv2.imread(img_path) 
print (img_orig.shape)
# Out:
# (4032, 3024, 3)

# %% [markdown]
# Height, Width, channel 순서임

# %%
model_dir = os.getenv('HOME')+'/aiffel/human_segmentation/models'
tf.io.gfile.makedirs(model_dir)

print ('temp directory:', model_dir)
# Out:
# temp directory: /aiffel/aiffel/human_segmentation/models

# %%
class DeepLabModel(object):
    INPUT_TENSOR_NAME = 'ImageTensor:0'
    OUTPUT_TENSOR_NAME = 'SemanticPredictions:0'
    INPUT_SIZE = 513
    FROZEN_GRAPH_NAME = 'frozen_inference_graph'

    # __init__()에서 모델 구조를 직접 구현하는 대신, tar file에서 읽어들인 그래프구조 graph_def를 
    # tf.compat.v1.import_graph_def를 통해 불러들여 활용하게 됩니다. 
    def __init__(self, tarball_path):
        self.graph = tf.Graph()
        graph_def = None
        tar_file = tarfile.open(tarball_path)
        for tar_info in tar_file.getmembers():
            if self.FROZEN_GRAPH_NAME in os.path.basename(tar_info.name):
                file_handle = tar_file.extractfile(tar_info)
                graph_def = tf.compat.v1.GraphDef.FromString(file_handle.read())
                break
        tar_file.close()

        with self.graph.as_default():
    	    tf.compat.v1.import_graph_def(graph_def, name='')

        self.sess = tf.compat.v1.Session(graph=self.graph)

    # 이미지를 전처리하여 Tensorflow 입력으로 사용 가능한 shape의 Numpy Array로 변환합니다.
    def preprocess(self, img_orig):
        height, width = img_orig.shape[:2]
        resize_ratio = 1.0 * self.INPUT_SIZE / max(width, height)
        target_size = (int(resize_ratio * width), int(resize_ratio * height)) #여기서 차원을 왜 바꾸는건가
        resized_image = cv2.resize(img_orig, target_size) #cv2.resize => Width, Height순임 => 이미지 shape고과는 다름
        resized_rgb = cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB)
        img_input = resized_rgb
        return img_input
        
    def run(self, image):
        img_input = self.preprocess(image)

        # Tensorflow V1에서는 model(input) 방식이 아니라 sess.run(feed_dict={input...}) 방식을 활용합니다.
        batch_seg_map = self.sess.run(
            self.OUTPUT_TENSOR_NAME,
            feed_dict={self.INPUT_TENSOR_NAME: [img_input]})

        seg_map = batch_seg_map[0]
        return cv2.cvtColor(img_input, cv2.COLOR_RGB2BGR), seg_map

# %%
download_path = os.path.join(model_dir, 'deeplab_model.tar.gz')
if not os.path.exists(download_path):
    urllib.request.urlretrieve(_DOWNLOAD_URL_PREFIX + 'deeplabv3_mnv2_pascal_train_aug_2018_01_29.tar.gz',
                   download_path)

MODEL = DeepLabModel(download_path)
print('model loaded successfully!')
# Out:
# model loaded successfully!

# %%
img_resized, seg_map = MODEL.run(img_orig)
print (img_orig.shape, img_resized.shape, seg_map.max())
# Out:
# (4032, 3024, 3) (513, 384, 3) 15

# %%
LABEL_NAMES = [
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tv'
]
len(LABEL_NAMES)
# Out:
# 21

# %% [markdown]
# ## 1-1 사람 segmentation

# %%
img_mask_up = cv2.resize(img_mask, img_orig.shape[:2][::-1], interpolation=cv2.INTER_LINEAR) #cv2.resize는 Width Height순임
img_show = img_resized.copy()
seg_map = np.where(seg_map == 15, 15, 0) # 예측 중 사람만 추출
img_mask = seg_map * (255/seg_map.max()) # 255 normalization
img_mask = img_mask.astype(np.uint8)
color_mask = cv2.applyColorMap(img_mask, cv2.COLORMAP_JET)
img_show = cv2.addWeighted(img_show, 0.6, color_mask, 0.4, 0.0)

plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
_, img_mask_up = cv2.threshold(img_mask_up, 128, 255, cv2.THRESH_BINARY)

ax = plt.subplot(1,2,1)
plt.imshow(img_mask_up, cmap=plt.cm.binary_r)
ax.set_title('Original Size Mask')

ax = plt.subplot(1,2,2)
plt.imshow(img_mask, cmap=plt.cm.binary_r)
ax.set_title('DeepLab Model Mask')

plt.show()

# %%
img_orig_blur = cv2.blur(img_orig, (10,10)) #(13,13)은 blurring  kernel size를 뜻합니다. 
plt.imshow(cv2.cvtColor(img_orig_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_mask_color = cv2.cvtColor(img_mask_up, cv2.COLOR_GRAY2BGR)
img_bg_mask = cv2.bitwise_not(img_mask_color)
img_bg_blur = cv2.bitwise_and(img_orig_blur, img_bg_mask)
plt.imshow(cv2.cvtColor(img_bg_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
fig = plt.figure(figsize = (12, 6))

ax = plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img_orig, cv2.COLOR_BGR2RGB))
ax.set_title("Original_picture")


ax = plt.subplot(1,2,2)
img_concat = np.where(img_mask_color==255, img_orig, img_bg_blur)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
ax.set_title("Outfocusing_picture")

plt.show()

# %% [markdown]
# ## 1-2 Segmentation 고양이 추출

# %%
img_path = os.getenv('HOME')+'/aiffel/human_segmentation/images/cat.jpg'   
img_orig_cat = cv2.imread(img_path)

# %%
img_resized, seg_map = MODEL.run(img_orig_cat)
print (img_orig.shape, img_resized.shape, seg_map.max())
# Out:
# (4032, 3024, 3) (338, 513, 3) 16

# %%
img_show = img_resized.copy()
seg_map = np.where(seg_map == LABEL_NAMES.index('cat'), LABEL_NAMES.index('cat'), 0) # 예측 중 사람만 추출
img_mask = seg_map * (255/seg_map.max()) # 255 normalization
img_mask = img_mask.astype(np.uint8)
color_mask = cv2.applyColorMap(img_mask, cv2.COLORMAP_JET)
img_show = cv2.addWeighted(img_show, 0.6, color_mask, 0.4, 0.0)

plt.imshow(cv2.cvtColor(img_show, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_mask_up = cv2.resize(img_mask, img_orig_cat.shape[:2][::-1], interpolation=cv2.INTER_LINEAR) #cv2.resize는 Width Height순임
_, img_mask_up = cv2.threshold(img_mask_up, 128, 255, cv2.THRESH_BINARY)

ax = plt.subplot(1,2,1)
plt.imshow(img_mask_up, cmap=plt.cm.binary_r)
ax.set_title('Original Size Mask')

ax = plt.subplot(1,2,2)
plt.imshow(img_mask, cmap=plt.cm.binary_r)
ax.set_title('DeepLab Model Mask')

plt.show()

# %%
img_orig_blur = cv2.blur(img_orig_cat, (10,10)) #(13,13)은 blurring  kernel size를 뜻합니다. 
plt.imshow(cv2.cvtColor(img_orig_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
img_mask_color = cv2.cvtColor(img_mask_up, cv2.COLOR_GRAY2BGR)
img_bg_mask = cv2.bitwise_not(img_mask_color)
img_bg_blur = cv2.bitwise_and(img_orig_blur, img_bg_mask)
plt.imshow(cv2.cvtColor(img_bg_blur, cv2.COLOR_BGR2RGB))
plt.show()

# %%
fig = plt.figure(figsize = (12, 6))

ax = plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(img_orig_cat, cv2.COLOR_BGR2RGB))
ax.set_title("Original_picture")
ax.axis("off")

ax = plt.subplot(1,2,2)
img_concat = np.where(img_mask_color==255, img_orig_cat, img_bg_blur)
plt.imshow(cv2.cvtColor(img_concat, cv2.COLOR_BGR2RGB))
ax.set_title("Outfocusing_picture")
ax.axis("off")
plt.show()

# %% [markdown]
# ## 1-3 크로마키사진

# %%
img_path = os.getenv('HOME')+'/aiffel/human_segmentation/images/background.jpg' 
img_background = cv2.imread(img_path)

# %%
plt.imshow(cv2.cvtColor(img_background, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
img_background = cv2.resize(img_background, img_orig_cat.shape[:2][::-1]) #cv2.resize는 Width Height순임
img_mask_up = cv2.resize(img_mask, img_orig_cat.shape[:2][::-1], interpolation=cv2.INTER_LINEAR) #cv2.resize는 Width Height순임

# %%
_, img_mask_up = cv2.threshold(img_mask_up, 128, 255, cv2.THRESH_BINARY)
img_mask_color = cv2.cvtColor(img_mask_up, cv2.COLOR_GRAY2BGR)

# %%
img_chromakey = np.where(img_mask_color==255, img_orig_cat, img_background)

# %%
plt.imshow(cv2.cvtColor(img_chromakey, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %% [markdown]
# ## 회고

# %% [markdown]
# 금요일부터 몸이 좋지않아 아예 신경을 쓰지못해 이번엔 거의 아무런 실험을 해볼 수가 없었다.
#
#
# 이미지의 차원인 H,W,C에 대해서 메소드마다 순서가 다른것을 이해할 수 있었고, segmentation의 모델 중 유명한 U-NET의 구조에 encoder-decoder부분에서 decoder에 encoder부분을 concat해주는 부분이 흥미로웠었다.
